# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
sys.path.append('../lib/pymdlrs')
sys.path.append('..')
import matplotlib.pyplot as plt
from sklearn import datasets
from src.util.plotting import rmse, logloss, run_and_plot
from sklearn.linear_model import ARDRegression
from src.ulnml.least_square_regression import RidgeULNML
from prac_mdl_comp import RidgeMDLCOMP

# %% [markdown]
# # Test

# %% [markdown]
# **basic fit**

# %%
X, y, coef = datasets.make_regression(n_samples=500, n_features=5, n_informative=5, random_state=50,
                                      noise=1, effective_rank=5, coef=True, bias=0)
run_and_plot(X, y, "Test RMSE", rmse, n_jobs=1)
# plt.ylim(1.0, 1.2)
# Out:
# running ridge+CV ..
# running lasso+CV ..
# running RandomSearch ..
# running RVM ..
# running MDL-RS ..
# running MDL-COMP ..
# (1.0, 1.2)

# %%
X, y, coef = datasets.make_regression(n_samples=500, n_features=5, n_informative=5, random_state=42,
                                      noise=1, effective_rank=5, coef=True, bias=0)
run_and_plot(X, y, "Test Log-loss", logloss)
# plt.ylim(0, 5)

# %% [markdown]
# # Synthetic (Correlated, RMSE)

# %%
X, y, coef = datasets.make_regression(n_samples=50, n_features=5, n_informative=2, random_state=42,
                                      noise=1, effective_rank=2, coef=True, bias=0)
rseults = run_and_plot(X, y, "Test RMSE", rmse)
# plt.ylim(0.5, 1.5)

# %%
X, y, coef = datasets.make_regression(n_samples=200, n_features=20, n_informative=10, random_state=42,
                                      noise=1, effective_rank=10, coef=True, bias=0)
results = run_and_plot(X, y, "Test RMSE", rmse)
plt.ylim(0.5, 1.5)

# %%
X, y, coef = datasets.make_regression(n_samples=1000, n_features=100, n_informative=50, random_state=42,
                                      noise=1, effective_rank=50, coef=True, bias=10)
results = run_and_plot(X, y, "Test RMSE", rmse)
plt.ylim(1.0, 1.5)
# Out:
# running ridge+CV ..
# running lasso+CV ..
# running RandomSearch ..
# running RVM ..
# running MDL-RS ..
# (1.0, 1.5)

# %% [markdown]
# # Synthetic (Correlated, Likelihood)

# %%
X, y, coef = datasets.make_regression(n_samples=50, n_features=5, n_informative=2, random_state=42,
                                      noise=1, effective_rank=2, coef=True, bias=1)
results = run_and_plot(X, y, "Test Log-loss", logloss)
# plt.savefig("result/synthetic-correlated-p5.pdf")
# plt.ylim(None, 50)
# Out:
# running ridge+CV ..
# running lasso+CV ..
# running RandomSearch ..
# running RVM ..
# running MDL-RS ..
# running MDL-COMP ..
# (-0.9346566145459967, 50.0)

# %%
X, y, coef = datasets.make_regression(n_samples=200, n_features=20, n_informative=10, random_state=42, noise=1, effective_rank=10, coef=True, bias=1)
run_and_plot(X, y, "Test Log-loss", logloss)
plt.ylim(None, 150)
# plt.savefig("result/synthetic-correlated-p20.pdf")
# Out:
# running ridge+CV ..
# running lasso+CV ..
# running RandomSearch ..
# running RVM ..
# running MDL-RS ..
# (26.868222201858039, 150)

# %%
X, y, coef = datasets.make_regression(n_samples=1000, n_features=100, n_informative=50, random_state=42, noise=1, effective_rank=50, coef=True, bias=1)
run_and_plot(X, y, "Test Log-loss", logloss)
plt.ylim(None, 600)
plt.savefig("result/synthetic-correlated-p100-whole.pdf")
# plt.savefig("result/synthetic-correlated-p100-detail.pdf")
# Out:
# running ridge+CV ..
# running lasso+CV ..
# running RandomSearch ..
# running RVM ..
# running MDL-RS ..

# %% [markdown]
# # Synthetic (Uncorrelated, RMSE)

# %%
X, y, coef = datasets.make_regression(n_samples=50, n_features=5, n_informative=2, random_state=42, noise=1, coef=True, effective_rank=5, bias=1)
run_and_plot(X, y, "Test RMSE", rmse)
plt.ylim(0.5, 2)
# Out:
# running ridge+CV ..
# running lasso+CV ..
# running RandomSearch ..
# running RVM ..
# running MDL-RS ..
# (0.5, 2)

# %%
X, y, coef = datasets.make_regression(n_samples=200, n_features=20, n_informative=10, random_state=42, noise=1, coef=True, effective_rank=20, bias=1)
run_and_plot(X, y, "Test RMSE", rmse)
plt.ylim(0.5, 2)
# Out:
# running ridge+CV ..
# running lasso+CV ..
# running RandomSearch ..
# running RVM ..
# running MDL-RS ..
# (0.5, 2)

# %%
X, y, coef = datasets.make_regression(n_samples=1000, n_features=100, n_informative=50, random_state=42, noise=1, coef=True, effective_rank=100, bias=1)
run_and_plot(X, y, "Test RMSE", rmse)
plt.ylim(1, 1.5)
# Out:
# running ridge+CV ..
# running lasso+CV ..
# running RandomSearch ..
# running RVM ..
# running MDL-RS ..
# (1, 1.5)

# %% [markdown]
# # Synthetic (Uncorrelated, Likelihood)

# %%
X, y, coef = datasets.make_regression(n_samples=50, n_features=5, n_informative=2, random_state=42, noise=1, effective_rank=5, coef=True, bias=1)
run_and_plot(X, y, "Test Log-loss", logloss)
plt.ylim(10, 40)
# Out:
# running ridge+CV ..
# running lasso+CV ..
# running RandomSearch ..
# running RVM ..
# running MDL-RS ..
# (10, 40)

# %%
X, y, coef = datasets.make_regression(n_samples=200, n_features=20, n_informative=10, random_state=42, noise=1, effective_rank=20, coef=True, bias=1)
run_and_plot(X, y, "Test Log-loss", logloss)
plt.ylim(50, 150)
# Out:
# running ridge+CV ..
# running lasso+CV ..
# running RandomSearch ..
# running RVM ..
# running MDL-RS ..
# (50, 150)

# %%
X, y, coef = datasets.make_regression(n_samples=500, n_features=100, n_informative=50, random_state=42, noise=1, effective_rank=100, coef=True, bias=1)
run_and_plot(X, y, "Test Log-loss", logloss)
plt.ylim(250, 700)
# Out:
# running ridge+CV ..
# running lasso+CV ..
# running RandomSearch ..
# running RVM ..
# running MDL-RS ..
