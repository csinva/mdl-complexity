# %%
import os
from os.path import join as oj
import sys, time
sys.path.insert(1, oj(sys.path[0], '..'))  # insert parent path
import seaborn as sns
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pmlb
from tqdm import tqdm
from copy import deepcopy
import pickle as pkl
import pandas as pd
import data
import numpy.linalg as npl 
import numpy.random as npr
from scipy.optimize import minimize
# from process_results import process_results, aggregate_results, best_ridge
from scipy.stats import ortho_group
from sklearn.linear_model import LinearRegression, RidgeCV
import scipy.linalg as scl
import pickle
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

save_dir = 'results'
os.makedirs(save_dir, exist_ok=True)

# %%
def loc_calc_thetahat(l):
    inv = npl.pinv(X_train.T @ X_train + l * np.eye(d))
#     inv = eigenvecs @ npl.pinv(np.eye(d) + np.diag(eigenvals)) @ eigenvecs.T
    return inv @ X_train.T @ y_train

def loc_mdl1_loss(l):
    thetahat = loc_calc_thetahat(l)
    mse_norm = npl.norm(y_train - X_train @ thetahat)**2 / (2 * var)
    theta_norm = npl.norm(thetahat)**2 / (2 * var)
    eigensum = 0.5 * np.sum(np.log((eigenvals + l) / l))
    return (mse_norm + theta_norm + eigensum) / n


def loc_mdl1_loss_ret_all(l):
    thetahat = loc_calc_thetahat(l)
    mse_norm = npl.norm(y_train - X_train @ thetahat)**2 / (2 * var)
    theta_norm = npl.norm(thetahat)**2 / (2 * var)
    eigensum = 0.5 * np.sum(np.log((eigenvals + l) / l))
    return mse_norm/n , theta_norm/n,  eigensum / n

def g(a, b):
    val = np.sqrt(a*(1+np.sqrt(b))**2+1)
    val -= np.sqrt(a*(1-np.sqrt(b))**2+1)
    val = val**2
    return(val/4)

def thm3(gammas, snr):
    delta = g(snr, gammas)
    bnd = gammas * np.log(1+snr-delta)
    bnd += np.log(1+gammas * snr - delta)
    bnd -= delta/snr
    return(bnd)

# %%
cs=sns.color_palette()

# %% [markdown]
# ## Load Results

# %%
file_name = 'mdl_results_d_100_200.txt'
file = open(file_name, 'rb')
results = pickle.load(file)
# results

# %% [markdown]
# ## Plot results

# %%
import matplotlib as mpl
label_size = 20
mpl.rcParams['xtick.labelsize'] = label_size 
mpl.rcParams['ytick.labelsize'] = label_size 
mpl.rcParams['axes.labelsize'] = label_size
mpl.rcParams['axes.titlesize'] = 14
mpl.rcParams['figure.titlesize'] = 10
# mpl.rcParams['lines.markersize'] = 8
mpl.rcParams['grid.linewidth'] = 2.5
mpl.rcParams['legend.fontsize'] = 20
# pylab.rcParams['xtick.major.pad']=5
# pylab.rcParams['ytick.major.pad']=5

# %%
ds = results["ds"]
gammas = results["gammas"]
mdl_theory = results["mdl_theory"]
mdl_practice = results["mdl_practice"]
thm3_bnds = results["mdl_thm_3"]
mse = results["mse"]
eigsum = results["eigsum"]
tnorm = results["tnorm"]

# plt.figure(figsize=[5, 5])

mpl.rcParams['legend.fontsize'] = 20
lss = ['-', '--', '-.', ':']
plt.figure(figsize=[8, 6])
for j, d in enumerate(ds):
    ns = np.asarray(d/gammas, dtype=int)
    plt.plot(d/ns, mdl_theory.mean(0)[j, :], color=cs[j], linestyle=lss[j],linewidth=4.,  label='d=%d'%(d))
plt.grid(True, alpha=0.5, linewidth=1.)
plt.legend(frameon=False)
plt.title('MDL-COMP', fontweight='bold', fontsize=20)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('d/n')
plt.tight_layout()
plt.savefig('mdl_theory.pdf')
plt.show()

plt.figure(figsize=[8, 6])
for j, d in enumerate(ds):
    ns = np.asarray(d/gammas, dtype=int)
    plt.plot(d/ns, mdl_practice.mean(0)[j, :], color=cs[j], linestyle=lss[j],linewidth=4.,  label='d=%d'%(d))
plt.title('Prac-MDL-COMP', fontweight='bold', fontsize=20)
plt.xscale('log')
plt.legend(frameon=False)
plt.xlabel('d/n')
plt.grid(True, alpha=0.5, linewidth=1.)
plt.tight_layout()

plt.savefig('mdl_practical.pdf')
plt.show()


plt.figure(figsize=[8, 6])
d = ds[0]
ns = np.asarray(d/gammas, dtype=int)
plt.plot(d/ns, mdl_theory.mean(0)[0, :], color=cs[0], linestyle='-',linewidth=4.,  label='MDL-COMP')
plt.plot(d/ns, thm3_bnds[d], color=cs[0], linestyle=':',linewidth=4.,  label='(RMT) MDL-COMP')
plt.plot(d/ns, mdl_practice.mean(0)[0, :], color=cs[0], linestyle='--',linewidth=4.,  label='Prac-MDL-COMP')
plt.legend(frameon=False)
plt.title('Comparison of MDL-complexities (d=%d)'%d, fontweight='bold', fontsize=20)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('d/n')
plt.grid(True, alpha=0.5, linewidth=1.)
plt.tight_layout()

plt.savefig('mdl_comparison_all_bounds.pdf')
plt.show()



plt.figure(figsize=[8, 6])
plt.plot(d/ns, mdl_practice.mean(0)[0, :], color=cs[0], linestyle='-', linewidth=4.,  label='Prac-MDL-COMP')
plt.plot(d/ns, mse.mean(0)[0, :], color=cs[1], linestyle='-.', linewidth=4.,label='In-sample MSE')
plt.plot(d/ns, eigsum.mean(0)[0, :], color=cs[2], linestyle='--',linewidth=4.,  label='Eig. Sum')
plt.plot(d/ns, tnorm.mean(0)[0, :], color=cs[3], linestyle=':',  linewidth=4., label='Theta Norm')
plt.xscale('log')
plt.xlabel('d/n')
# plt.ylim([0., 1.75])
plt.grid(True, alpha=0.5, linewidth=1.)
plt.title('Decomposing Prac-MDL-COMP (d=%d)'%d, fontweight='bold', fontsize=20)
plt.legend(frameon=False)
plt.tight_layout()
plt.savefig('mdl_practical_details.pdf')
plt.show()

# %% [markdown]
# ## Run simulations

# %%
n = 400

# %%
num_trials = 10
gamma_inv = np.array([5e-2, 1e-1, 0.5, 0.75, 0.9, 1,
                                  1.2, 1.5, 2, 5, 7.5, 1e1, 2e1, 4e1])

gammas = np.array([5e-2, 1e-1, 0.2, 0.5, 0.75, 0.9, 0.95, 1.,  1.05,  1.25, 1.5,  1.75, 1.95, 2., 2.05, 2.25, 2.5, 5., 10., 20.])

noise_std = 0.1
n_test = 1000

ds = [100, 200]
ns = np.asarray(ds[0]/gammas, dtype=int)

mdl_practice = np.zeros((num_trials,  len(ds), len(ns)))
mdl_theory = np.zeros((num_trials, len(ds), len(ns)))
mdl_theory_mean = np.zeros((num_trials, len(ds), len(ns)))
mdl_theory_lam  = np.zeros((num_trials, len(ds), len(ns)))
mse = np.zeros((num_trials, len(ds), len(ns)))
tnorm = np.zeros((num_trials, len(ds), len(ns)))
eigsum = np.zeros((num_trials, len(ds), len(ns)))
mse_test = np.zeros((num_trials, len(ds), len(ns)))

for j, d in enumerate(ds):
    ns = np.asarray(d/gammas, dtype=int)
    for k, n in enumerate(ns):
        print(d, n)
        X_train = npr.randn(n, d) / np.sqrt(n)
        X_test = npr.randn(n_test, d)
        eigenvals, eigenvecs = npl.eig(X_train.T @ X_train)
        
        for i in tqdm(range(num_trials)):
            
            beta_star = npr.randn(d)
            beta_star /= npl.norm(beta_star)    
            beta_star *= 1. #

            w = eigenvecs.T  @ beta_star
            
            y_train = X_train @ beta_star + noise_std * npr.randn(n)
            y_test =  X_test @ beta_star # + noise_std *  npr.randn(n_test)

            var = noise_std**2
            opt_solved = minimize(loc_mdl1_loss, x0=1e-10)
            lambda_opt = opt_solved.x
            
            mdl_practice[i, j, k] = opt_solved.fun
            mdl_theory[i, j, k] = np.sum(np.log(1+ eigenvals * w**2 / var)) / n
            mdl_theory_mean[i, j, k] = np.sum(np.log(1+ eigenvals * np.mean(w**2) /var)) / n
            mdl_theory_lam[i, j, k] = np.sum(np.log(1+ eigenvals / lambda_opt)) / n
            mse[i, j, k], tnorm[i, j, k], eigsum[i, j, k] = loc_mdl1_loss_ret_all(lambda_opt)
            
            mse_test[i, j, k] = npl.norm(y_test- X_test @ loc_calc_thetahat(lambda_opt))**2 / n_test
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100 2000
#  10%|█         | 1/10 [00:00<00:07,  1.17it/s]
#
#
#
#
#  20%|██        | 2/10 [00:01<00:06,  1.19it/s]
#
#
#
#
#  30%|███       | 3/10 [00:02<00:05,  1.21it/s]
#
#
#
#
#  40%|████      | 4/10 [00:03<00:04,  1.22it/s]
#
#
#
#
#  50%|█████     | 5/10 [00:04<00:04,  1.23it/s]
#
#
#
#
#  60%|██████    | 6/10 [00:04<00:03,  1.24it/s]
#
#
#
#
#  70%|███████   | 7/10 [00:05<00:02,  1.24it/s]
#
#
#
#
#  80%|████████  | 8/10 [00:06<00:01,  1.25it/s]
#
#
#
#
#  90%|█████████ | 9/10 [00:07<00:00,  1.26it/s]
#
#
#
#
# 100%|██████████| 10/10 [00:08<00:00,  1.26it/s]
#
#
#
#
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100 1000
#  10%|█         | 1/10 [00:00<00:05,  1.64it/s]
#
#
#
#
#  20%|██        | 2/10 [00:01<00:04,  1.63it/s]
#
#
#
#
#  30%|███       | 3/10 [00:01<00:04,  1.63it/s]
#
#
#
#
#  40%|████      | 4/10 [00:02<00:03,  1.63it/s]
#
#
#
#
#  50%|█████     | 5/10 [00:03<00:03,  1.63it/s]
#
#
#
#
# ...

# %%
thm3_bnds = dict()
for d in ds:
    ns = np.asarray(d/gammas, dtype=int)
    thm3_bnds[d] = thm3(d/ns, npl.norm(beta_star)/var/d)

# %%
plt.figure(figsize=[18, 4])

for j, d in enumerate(ds):
    ns = np.asarray(d/gammas, dtype=int)
    plt.subplot(1, 4, j+1)
    plt.plot(d/ns, mdl_practice.mean(0)[j, :], color=cs[0], linestyle='-', linewidth=3., label='Practical Bound')
    plt.plot(d/ns, mdl_theory.mean(0)[j, :], color=cs[0], linestyle='--',linewidth=3.,  label='Thm-1 Bound')
    plt.plot(d/ns, thm3_bnds[d], color=cs[0], linestyle=':',linewidth=3.,  label='Thm-3 Bound')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel('d/n')
    if j==0:
        plt.legend()
    
    plt.subplot(1, 4, j+3)
    plt.plot(d/ns, mdl_practice.mean(0)[j, :], color=cs[j], linestyle='-', marker='D', label='MDL-COMP-Practical')
    plt.plot(d/ns, mse.mean(0)[j, :], color=cs[1], linestyle='-.', marker='D', label='mse')
    plt.plot(d/ns, eigsum.mean(0)[j, :], color=cs[2], linestyle='--',  marker='o', label='eigsum')
    plt.plot(d/ns, tnorm.mean(0)[j, :], color=cs[3], linestyle=':',  marker='s', label='tnorm')
#     plt.plot(d/ns, tnorm.mean(0)[j, :]+mse.mean(0)[j, :]+eigsum.mean(0)[j, :], 'k--')
    plt.xscale('log')
    plt.xlabel('d/n')
plt.tight_layout()
plt.show()
#     plt.subplot(122)
#     plt.loglog(d/ns, mdl_practice.mean(0)[j, :]/mdl_theory.mean(0)[j, :], color=cs[j])
# plt.xscale('log')
#     plt.legend()

# %% [markdown]
# ## Change d

# %%
npr.seed(15430)
num_trials = 5

gammas = np.hstack((np.logspace(-1, -0.1, 5),
        np.logspace(-0.05, 0.1, 4),
        np.logspace(0.2, 1., 5)))

# gammas = np.array([0.1, 0.5, 1., 2., 5.])
noise_std = 0.1
n_test = 1000

ns = np.array([400])
ds = np.asarray(gammas*ns[0], dtype=int)

mdl_practice = np.zeros((num_trials,  len(ds), len(ns)))
mdl_theory = np.zeros((num_trials, len(ds), len(ns)))
mdl_theory_mean = np.zeros((num_trials, len(ds), len(ns)))
mdl_theory_lam  = np.zeros((num_trials, len(ds), len(ns)))
mse = np.zeros((num_trials, len(ds), len(ns)))
tnorm = np.zeros((num_trials, len(ds), len(ns)))
eigsum = np.zeros((num_trials, len(ds), len(ns)))

mse_mdl = np.zeros((num_trials, len(ds), len(ns))) ## this is mdl's

mse_ols = np.zeros((num_trials, len(ds), len(ns)))
mse_ridge = np.zeros((num_trials, len(ds), len(ns)))

norm_beta = np.zeros((len(ds), len(ns)))
epow = 0.
for k, n in enumerate(ns):
    ds = np.asarray(np.maximum(2, gammas*n), dtype=int)

    print('n=%d'%n)
    for j, d in enumerate(ds):
        evals = np.array([1/i**epow for i in range(1, d+1)])
        print('d=%d'%d)
        X_train = npr.randn(n, d) / np.sqrt(n) @ np.diag(evals)
        X_test = npr.randn(n_test, d) @ np.diag(evals)
        eigenvals, eigenvecs = scl.eigh(X_train.T @ X_train)
        
        w = 1./np.arange(1, d+1)**0.25 / np.maximum(np.sqrt(1e-2), np.sqrt(np.maximum(0., eigenvals)))
#         w /= npl.norm(w)

        beta_star = eigenvecs.T @ w

        norm_beta[j, k] = npl.norm(beta_star)
        for i in range(num_trials):
        
            y_train = X_train @ beta_star + noise_std * npr.randn(n)
            y_test =  X_test @ beta_star # + noise_std *  npr.randn(n_test)

            var = noise_std**2
            mdl_theory[i, j, k] = np.sum(np.log(1+ eigenvals * w**2 / var)) / n
            
            m = RidgeCV(fit_intercept=False, alphas=np.logspace(-5, 6, num=100, base=10))
            m.fit(X_train, y_train)            
            mse_ridge[i, j, k] = npl.norm(y_test - X_test @ m.coef_)**2 /  n_test
                        
            ols = LinearRegression(fit_intercept=False)
            ols.fit(X_train, y_train)

            mse_ols[i, j, k] = npl.norm(y_test - X_test @ ols.coef_)**2 / n_test
# Out:
# n=400
# d=40
# d=67
# d=112
# d=189
# d=317
# d=356
# d=400
# d=448
# d=503
# d=633
# d=1004
# d=1592
# d=2523
# d=4000

# %% [markdown]
# ## Dump Results

# %%
file_name = 'remove_double_descent.txt'
results = {'ns': ns, 'ds': ds, 
           'gammas': gammas,
           'noise_var': noise_std**2,
           'num_trials': num_trials, 
           'norm_beta': norm_beta, 
           'mse_ridge': mse_ridge, 
           'mse_ols':mse_ols, 
           'mdl_theory': mdl_theory,
          }
file = open(file_name, 'wb')
pickle.dump(results, file)
file.close()

# %% [markdown]
# ## Load Results

# %%
file_name = 'remove_double_descent.txt'
file = open(file_name, 'rb')
results = pickle.load(file)
file.close()

# %%
ns = results["ns"]
gammas = results["gammas"]
mdl_theory = results["mdl_theory"]
norm_beta = results["norm_beta"]
mse_ridge = results["mse_ridge"]
mse_ols = results["mse_ols"]

for k, n in enumerate(ns):
    plt.figure(figsize=[8, 6])
    ds = np.asarray(np.maximum(2, gammas*n), dtype=int)
    plt.loglog(ds/n, mse_ols.mean(0)[:, k], color=cs[0], linestyle='--', linewidth=4., marker='d',  markersize=10, label='OLS Test-MSE')
    plt.loglog(ds/n, mse_ridge.mean(0)[:, k], color=cs[2], linestyle=':', linewidth=4., marker='s',  markersize=8,  label='Ridge Test-MSE')
    plt.loglog(ds/n, mdl_theory.mean(0)[:, k], color=cs[1], linestyle='-',linewidth=3.,  label='MDL-COMP')
    plt.loglog(ds/n, norm_beta[:, k]**2, color=cs[3], linestyle="-.", linewidth=3.,  label=r'$\Vert \theta_* \Vert_2^2$')
    plt.xlabel('d/n')
    plt.legend(frameon=False, fontsize=20)
    plt.grid(True, alpha=0.5, linewidth=1.)
    plt.tight_layout()
    plt.savefig('remove_double_descent_part1_n_%d.pdf'%n)
    plt.show()

for k, n in enumerate(ns):
    plt.figure(figsize=[8, 6])
    plt.semilogy(mdl_theory.mean(0)[:, k], mse_ols.mean(0)[:, k], color=cs[0], linestyle='--', linewidth=4., marker='d',  markersize=10, label='OLS Test-MSE')
    plt.semilogy(mdl_theory.mean(0)[:, k], mse_ridge.mean(0)[:, k], color=cs[2], linestyle=':', linewidth=3., marker='s',  markersize=8,  label='Ridge Test-MSE')
    plt.xlabel('MDL-COMP')
    plt.xticks([0.5, 1., 1.5, 2.], [0.5, 1., 1.5, 2.])
    plt.legend(frameon=False, fontsize=20, loc='center left')    
    plt.tight_layout()
    plt.grid(True, alpha=0.5, linewidth=1.)
    plt.savefig('remove_double_descent_part2_n_%d.pdf'%n)
    plt.show()

# %%
# thm3_bnds_new = dict()
# for k, n in enumerate(ns):
#     ds = np.asarray(n*gammas, dtype=int)
#     thm3_bnds_new[n] = thm3(ds/n, 1./var*norm_beta[:, k]**2/ds)

# %% [markdown]
# ## Just MDL Expressions with simple decay

# %%
gammas = np.logspace(-2., 2., 11)

noise_std = 0.1

ns = np.array([400])
ds = np.asarray(gammas*ns[0], dtype=int)

epows = np.linspace(0., .5, 2)
thm_mdl_comp = np.zeros((len(ds), len(epows)))

thm_mdl_comp_2 = np.zeros((len(ds), len(epows)))
C = 100.

for k, epow in enumerate(epows):
    for j, d in enumerate(ds):
        ew = 1./np.arange(1, d+1)**epow
        ew /= np.sum(ew)
        ew *= d
        thm_mdl_comp[j, k] = np.sum(np.log(1+ ew[:min(d, ns[0])])) / ns[0]
        
        ew/= d
        thm_mdl_comp_2[j, k] = np.sum(np.log(1+ 100*ew[:min(d, ns[0])])) / ns[0]

# %%
import matplotlib as mpl
label_size = 20
mpl.rcParams['xtick.labelsize'] = label_size 
mpl.rcParams['ytick.labelsize'] = label_size 
mpl.rcParams['axes.labelsize'] = label_size
mpl.rcParams['axes.titlesize'] = 14
mpl.rcParams['figure.titlesize'] = 10
# mpl.rcParams['lines.markersize'] = 8
mpl.rcParams['grid.linewidth'] = 2.5
mpl.rcParams['legend.fontsize'] = 12
# pylab.rcParams['xtick.major.pad']=5
# pylab.rcParams['ytick.major.pad']=5

# %%
lss = ['-', '--', '-.', ':']
mss = ['s', 'd', 'o', '^']
plt.figure(figsize=[8, 6])
for k, epow in enumerate(epows):
    if epow==0:
        plt.loglog(gammas, thm_mdl_comp[:, k], label=r'$(\alpha, S_d)= (%d, d)$'%epow, marker=mss[k], linestyle=lss[k], linewidth=4., markersize=10)
        plt.loglog(gammas, thm_mdl_comp_2[:, k], label=r'$(\alpha, S_d)= (%d, 100)$'%epow, linestyle=lss[k+2],  marker=mss[k+2],  linewidth=4., markersize=10)
    else:
        plt.loglog(gammas, thm_mdl_comp[:, k], label=r'$(\alpha, S_d)= (%.1f, d)$'%epow, marker=mss[k], linestyle=lss[k], linewidth=4., markersize=10)
        plt.loglog(gammas, thm_mdl_comp_2[:, k], label=r'$(\alpha, S_d)= (%.1f, 100)$'%epow, linestyle=lss[k+2],  marker=mss[k+2],  linewidth=4., markersize=10)
# plt.axvline(1., color='k', alpha=0.5, linewidth=2., linestyle=':')
plt.ylabel('MDL-COMP')
plt.grid(True, alpha=0.5, linewidth=1.)
plt.ylim([1e-3, 3])
plt.legend(loc='lower center', frameon=False, fontsize=20)
plt.xlabel('d/n')
plt.tight_layout()
plt.savefig('theory_decay_mdl.pdf')
plt.show()

# %% [markdown]
# ## MDL Expressions with Random Matrix with Decay

# %%
gammas_new = np.logspace(-1., 1., 5)

# %%
gammas_new = np.logspace(-1., 1., 5)

noise_std = 0.1

ns = np.array([100])
n = ns[0]
ds = np.asarray(gammas_new*ns[0], dtype=int)

# %%
npr.seed(0)
num_trials = 5
rmt_mdl_comp = np.zeros((num_trials,len(ds), len(epows)))

rmt_mdl_comp_2 = np.zeros((num_trials, len(ds), len(epows)))

for p in tqdm(range(num_trials)):
    for k, epow in enumerate(epows):
        for j, d in enumerate(ds):
            evals = np.array([1/i**epow for i in range(1, d+1)])
            print('d=%d'%d)
            X_train = npr.randn(n, d) / np.sqrt(n) @ np.diag(evals)
            eigenvals, eigenvecs = scl.eigh(X_train.T @ X_train)

            beta_star = npr.randn(d)
            beta_star /= npl.norm(beta_star)

            w = eigenvecs.T @ beta_star

            rmt_mdl_comp[p, j, k] = np.sum(np.log(1+100* eigenvals * w**2/noise_std**2)) / ns[0]
            rmt_mdl_comp_2[p, j, k] = np.sum(np.log(1+ d*eigenvals * w**2/noise_std**2)) / ns[0]
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# d=10
# d=31
# d=100
# d=316
# d=1000
# d=10
# d=31
# d=100
# d=316
# d=1000
#  20%|██        | 1/5 [00:00<00:02,  1.84it/s]
# d=10
# d=31
# d=100
# d=316
# d=1000
# d=10
# d=31
# d=100
# d=316
# d=1000
#  40%|████      | 2/5 [00:01<00:01,  1.85it/s]
# d=10
# d=31
# d=100
# d=316
# d=1000
# d=10
# d=31
# d=100
# d=316
# d=1000
#  60%|██████    | 3/5 [00:01<00:01,  1.85it/s]
# d=10
# d=31
# d=100
# d=316
# d=1000
# d=10
# d=31
# d=100
# d=316
# d=1000
#  80%|████████  | 4/5 [00:02<00:00,  1.86it/s]
# d=10
# d=31
# d=100
# d=316
# d=1000
# d=10
# d=31
# d=100
# d=316
# d=1000
# 100%|██████████| 5/5 [00:02<00:00,  1.87it/s]

# %%
lss = ['-', '--', '-.', ':']
mss = ['s', 'd', 'o', '^']

plt.figure(figsize=[8, 6])
for k, epow in enumerate(epows):
    if epow==0:
        plt.loglog(gammas_new, rmt_mdl_comp_2.mean(0)[:, k], label=r'$(\alpha, R_d)= (%d, d)$'%epow, marker=mss[k], linestyle=lss[k], linewidth=4., markersize=10)
        plt.loglog(gammas_new, rmt_mdl_comp.mean(0)[:, k], label=r'$(\alpha, R_d)= (%d, 100)$'%epow, 
                   linestyle=lss[k+2],  marker=mss[k+2],  linewidth=4., markersize=10)
    else:
        plt.loglog(gammas_new, rmt_mdl_comp_2.mean(0)[:, k], label=r'$(\alpha, R_d)= (%.1f, d)$'%epow, marker=mss[k], 
                   linestyle=lss[k], linewidth=4., markersize=10)
        plt.loglog(gammas_new, rmt_mdl_comp.mean(0)[:, k], label=r'$(\alpha, R_d)= (%.1f, 100)$'%epow, linestyle=lss[k+2],  
                   marker=mss[k+2],  linewidth=4., markersize=10)
# plt.axvline(1., color='k', alpha=0.5, linewidth=2., linestyle=':')
plt.grid(True, alpha=0.5, linewidth=1.)
plt.ylabel('MDL-COMP')
plt.ylim([5e-2, 1e1])
plt.legend(frameon=False, fontsize=20, loc='lower center')
plt.xlabel('d/n')
plt.tight_layout()
plt.savefig('RMT_decay_mdl.pdf')
plt.show()

# %%
rmt_mdl_comp.mean(0)[:, 1]
# Out:
# array([0.43242953, 0.74894956, 0.77634125, 0.5994712 , 0.36975855])

# %%
file_name = 'mdl_complexities.txt'
results = {
            'gammas_new': gammas_new,
           'rmt_mdl_comp': rmt_mdl_comp, 
           'rmt_mdl_comp_2': rmt_mdl_comp_2, 
           'thm_mdl_comp': thm_mdl_comp, 
           'thm_mdl_comp_2':thm_mdl_comp_2, 
           'epows': epows,
            'r_ds': 'd, 100',
            's_ds': 'd, 100'
          }
file = open(file_name, 'wb')
pickle.dump(results, file)
file.close()

# %% [markdown]
# ## MDL New

# %% [markdown]
# ## Once again

# %%
npr.seed(0)
num_trials = 5

gammas = np.hstack((np.logspace(-1, -0.1, 5),
        np.logspace(-0.05, 0.1, 4),
        np.logspace(0.2, 1., 5)))

gammas = np.logspace(-1., 1.5, 6)
# gammas = np.array([0.1, 0.5, 1., 2., 5.])
noise_std = 1
n_test = 1000

ns = np.array([100])
ds = np.asarray(gammas*ns[0], dtype=int)

mdl_practice = np.zeros((num_trials,  len(ds), len(ns)))
mdl_theory = np.zeros((num_trials, len(ds), len(ns)))
mdl_theory_mean = np.zeros((num_trials, len(ds), len(ns)))
mdl_theory_lam  = np.zeros((num_trials, len(ds), len(ns)))
mse = np.zeros((num_trials, len(ds), len(ns)))
tnorm = np.zeros((num_trials, len(ds), len(ns)))
eigsum = np.zeros((num_trials, len(ds), len(ns)))

mse_mdl = np.zeros((num_trials, len(ds), len(ns))) ## this is mdl's

mse_ols = np.zeros((num_trials, len(ds), len(ns)))
mse_ridge = np.zeros((num_trials, len(ds), len(ns)))

norm_beta = np.zeros((len(ds), len(ns)))
epow = 0.5
for k, n in enumerate(ns):
    ds = np.asarray(np.maximum(2, gammas*n), dtype=int)

    print('n=%d'%n)
    for j, d in enumerate(ds):
        evals = np.array([1/i**epow for i in range(1, d+1)])
        print('d=%d'%d)
        X_train = npr.randn(n, d) / np.sqrt(n) @ np.diag(evals)
        X_test = npr.randn(n_test, d) @ np.diag(evals)
        eigenvals, eigenvecs = scl.eigh(X_train.T @ X_train)
        
        beta_star = npr.randn(d)
        beta_star /= npl.norm(beta_star)
        beta_star *= 10
        
        w = eigenvecs.T @ beta_star

        norm_beta[j, k] = npl.norm(beta_star)
        for i in range(num_trials):
        
            y_train = X_train @ beta_star + noise_std * npr.randn(n)
            y_test =  X_test @ beta_star # + noise_std *  npr.randn(n_test)

            var = noise_std**2
            mdl_theory[i, j, k] = np.sum(np.log(1+ eigenvals * w**2 / var)) / n
            
            m = RidgeCV(fit_intercept=False, alphas=np.logspace(-5, 6, num=100, base=10))
            m.fit(X_train, y_train)            
            mse_ridge[i, j, k] = npl.norm(y_test - X_test @ m.coef_)**2 /  n_test
                        
            ols = LinearRegression(fit_intercept=False)
            ols.fit(X_train, y_train)

            mse_ols[i, j, k] = npl.norm(y_test - X_test @ ols.coef_)**2 / n_test
# Out:
# n=100
# d=10
# d=31
# d=100
# d=316
# d=1000
# d=3162

# %%
for k, n in enumerate(ns):
    plt.figure(figsize=[8, 6])
    ds = np.asarray(np.maximum(2, gammas*n), dtype=int)
    plt.loglog(ds/n, mse_ols.mean(0)[:, k], color=cs[0], linestyle='--', linewidth=4., marker='d',  markersize=10, label='OLS Test-MSE')
    plt.loglog(ds/n, mse_ridge.mean(0)[:, k], color=cs[2], linestyle=':', linewidth=4., marker='s',  markersize=8,  label='Ridge Test-MSE')
    plt.loglog(ds/n, mdl_theory.mean(0)[:, k], color=cs[1], linestyle='-',linewidth=3.,  label='MDL-COMP')
    plt.loglog(ds/n, norm_beta[:, k]**2, color=cs[3], linestyle="-.", linewidth=3.,  label=r'$\Vert \theta_* \Vert_2^2$')
    plt.xlabel('d/n')
    plt.legend(frameon=False, fontsize=20)
    plt.grid(True, alpha=0.5, linewidth=1.)
    plt.tight_layout()
#     plt.savefig('remove_double_descent_part1_n_%d.pdf'%n)
    plt.show()

# for k, n in enumerate(ns):
#     plt.figure(figsize=[8, 6])
#     rmt_mdl_comp.mean(0)[:, 1]
#     plt.semilogy(rmt_mdl_comp.mean(0)[:, 1], mse_ols.mean(0)[:, k], color=cs[0], linestyle='--', linewidth=4., marker='d',  markersize=10, label='OLS Test-MSE')
#     plt.semilogy(rmt_mdl_comp.mean(0)[:, 1], mse_ridge.mean(0)[:, k], color=cs[2], linestyle=':', linewidth=3., marker='s',  markersize=8,  label='Ridge Test-MSE')

# #     plt.semilogy(mdl_theory.mean(0)[:, k], mse_ols.mean(0)[:, k], color=cs[0], linestyle='--', linewidth=4., marker='d',  markersize=10, label='OLS Test-MSE')
    
# #     plt.semilogy(mdl_theory.mean(0)[:, k], mse_ridge.mean(0)[:, k], color=cs[2], linestyle=':', linewidth=3., marker='s',  markersize=8,  label='Ridge Test-MSE')
#     plt.xlabel('MDL-COMP')
# #     plt.xticks([0.5, 1., 1.5, 2.], [0.5, 1., 1.5, 2.])
#     plt.legend(frameon=False, fontsize=20, loc='center left')    
#     plt.tight_layout()
#     plt.grid(True, alpha=0.5, linewidth=1.)
# #     plt.savefig('remove_double_descent_part2_n_%d.pdf'%n)
#     plt.show()

# %% [markdown]
# ## Fixed X

# %%
npr.seed(0)
num_trials = 1
gammas_new = np.logspace(-1., 1.5, 6)

noise_std = .1

ds = np.array([1000])
d = ds[0]
ns = np.asarray(d/gammas_new, dtype=int)

theta_type = ['inc', 'dec', 'rand']

norm_type = ['const', 'inc']

fixed_mdl_comp = {} 

X_train = npr.randn(max(ns), d) @ np.diag(np.arange(1, d+1)**-0.5)


for k, tt in enumerate(theta_type):
    fixed_mdl_comp[tt] = {}

    for i, nt in enumerate(norm_type):
        fixed_mdl_comp[tt][nt] = np.zeros(len(ns))
        
        for j, n in enumerate(ns):
            eigenvals, eigenvecs = scl.eigh(X_train[:n, :].T @ X_train[:n, :])
            if tt == "inc":
                tstar = 1.*np.arange(1, d+1)**0.5
            elif tt == "dec":
                tstar = (1.*np.arange(1, d+1)**0.5)[::-1]
            elif tt == "rand":
                tstar = npr.randn(d)
            
            tstar /= npl.norm(tstar)
            if nt == "const":
                tstar *= 1.
            elif nt == "inc":
                tstar *= np.sqrt(d)
            elif nt == "dec":
                tstar /= np.sqrt(d)
        
            w = eigenvecs.T @ tstar

            fixed_mdl_comp[tt][nt][j]  = 1.*np.sum(np.log(1+eigenvals * w**2/noise_std**2)) / n
            
        plt.loglog(gammas_new, fixed_mdl_comp[tt][nt], label=tt+' '+nt)
plt.legend()
plt.show()

# %% [markdown]
# # Dump Results

# %%
file_name = 'SOMETHING_NEW.txt'

# %%
results = {'ns': ns, 'ds': ds, 
           'num_trials': num_trials, 
           'beta_norm': npl.norm(beta_star), 
           'noise_var': noise_std**2,
           'gammas': gammas,
           'mse': mse, 
           'eigsum': eigsum, 
           'tnorm':tnorm,
           'mdl_practice': mdl_practice, 

           'mdl_theory':mdl_theory, 
           'mdl_thm_3': thm3_bnds,
           
#            'mdl_theory_lam': mdl_theory_lam, 
#            'mdl_theory_mean': mdl_theory_mean,

          }
file = open(file_name, 'wb')
pickle.dump(results, file)
file.close()
